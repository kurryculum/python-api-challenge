# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df=pd.read_csv("../output_data/cities.csv")
df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations=df[["Lat","Lng"]]
weight=df["Humidity"]
fig=gmaps.figure()
heatlayer=gmaps.heatmap_layer(locations, weights=weight)
fig.add_layer(heatlayer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
citie_narrows_df=df.loc[(df["Max Temp"] < 80) & (df["Max Temp"] > 70) & (df["Wind Speed"] < 10) & (df["Cloudiness"]==0), :]
citie_narrows_df=df.dropna()
citie_narrows_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = df[["City", "Country", "Lat", "Lng"]]
hotel_df.head()
# Out:
#         City Country    Lat     Lng
# 0  ostrovnoy      RU  68.05   39.51
# 1  mahebourg      MU -20.41   57.70
# 2    qaanaaq      GL  77.48  -69.36
# 3     zhuhai      CN  40.71  112.04
# 4  cape town      ZA -33.93   18.42

# %%
hotel_df["Hotel Name"]=""
hotel_df.head(1)
# Out:
# /Users/vineetsikriyahoo.com/opt/anaconda2/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         City Country    Lat    Lng Hotel Name
# 0  ostrovnoy      RU  68.05  39.51

# %%
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {
    "radius": 5000,
    "types": "hotel",
    "key": g_key,
}
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    #print(lat, lng)
    
    
    # get hotel type from df
#     Hotel_type= row['Hotel Name']

#     # add keyword to params dict
    params["location"] = f"{lat},{lng}"
    

#     # assemble url and make API request
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    Hotel_type = requests.get(base_url, params=params)
    Hotel_type =Hotel_type.json()
    #print(Hotel_type)
    
#     print(f"Retrieving Results for Index {index}: {Hotel_name}.")
#     response = requests.get(base_url, params=params).json()
#     results = response['results']
    try:
        hotel_df.loc[index, "Hotel_name"] = Hotel_type["results"][0]["name"]

    except:
        print("hotel not found")
# Out:
# {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': 68.0603191, 'lng': 39.47403850000001}, 'viewport': {'northeast': {'lat': 68.0718151, 'lng': 39.5290122}, 'southwest': {'lat': 68.045485, 'lng': 39.445749}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png', 'name': 'Ostrovnoy', 'place_id': 'ChIJJS_Smg3-OEQRCNAsnX_ZMOE', 'reference': 'ChIJJS_Smg3-OEQRCNAsnX_ZMOE', 'scope': 'GOOGLE', 'types': ['locality', 'political'], 'vicinity': 'Ostrovnoy'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 68.0542983, 'lng': 39.5119819}, 'viewport': {'northeast': {'lat': 68.0557238302915, 'lng': 39.5134838302915}, 'southwest': {'lat': 68.05302586970849, 'lng': 39.5107858697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/worship_general-71.png', 'name': 'Chasovnya Nikolaya Chudotvortsa.', 'photos': [{'height': 1872, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102225767382632639660">Lora Andreeva</a>'], 'photo_reference': 'CkQ0AAAAM2UFzfMDhIy6qg6dHNd0VCiazXCHT_qtBAKIpbH6RXrM06mLoxINV2P_SllEZzR6z7F70C8KDoHQ5yLfSD1FIhIQ-CSe7b7SiRP_RWEk_NOVsRoUX7FuGF5qGMmXy9bz6Hx7vf5KD5M', 'width': 3328}], 'place_id': 'ChIJM97Oogr-OEQRPh-2NSxeldw', 'plus_code': {'compound_code': '3G36+PQ Ostrovnoy, Murmansk Oblast, Russia', 'global_code': '9GWX3G36+PQ'}, 'rating': 4.7, 'reference': 'ChIJM97Oogr-OEQRPh-2NSxeldw', 'scope': 'GOOGLE', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'user_ratings_total': 7, 'vicinity': 'Ostrovnoy'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 68.05481, 'lng': 39.50394800000001}, 'viewport': {'northeast': {'lat': 68.05592593029151, 'lng': 39.50464185000001}, 'southwest': {'lat': 68.05322796970849, 'lng': 39.50186645}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png', 'name': "Tsentral'naya Gorodskaya Bol'nitsa", 'opening_hours': {'open_now': True}, 'place_id': 'ChIJ6QoaBwv-OEQRdTaGyJpoeuw', 'plus_code': {'compound_code': '3G33+WH Ostrovnoy, Murmansk Oblast, Russia', 'global_code': '9GWX3G33+WH'}, 'reference': 'ChIJ6QoaBwv-OEQRdTaGyJpoeuw', 'scope': 'GOOGLE', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'vicinity': 'Заозерная ул., 1, Ostrovnoy'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 68.055926, 'lng': 39.5156651}, 'viewport': {'northeast': {'lat': 68.0573321302915, 'lng': 39.5167811802915}, 'southwest': {'lat': 68.05463416970849, 'lng': 39.5140832197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'name': 'Magazin', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJxXb6lPP_OEQR3gvGJPfNI6w', 'plus_code': {'compound_code': '3G48+97 Ostrovnoy, Murmansk Oblast, Russia', 'global_code': '9GWX3G48+97'}, 'rating': 5, 'reference': 'ChIJxXb6lPP_OEQR3gvGJPfNI6w', 'scope': 'GOOGLE', 'types': ['supermarket', 'grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 3, 'vicinity': 'Unnamed Road, Ostrovnoy'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 68.05524799999999, 'lng': 39.494236}, 'viewport': {'northeast': {'lat': 68.05650663029151, 'lng': 39.4953159302915}, 'southwest': {'lat': 68.05380866970849, 'lng': 39.4926179697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png', 'name': 'АЗС', 'place_id': 'ChIJC0D0DQz-OEQR5iav36VWsZE', 'plus_code': {'compound_code': '3F4V+3M Ostrovnoy, Murmansk Oblast, Russia', 'global_code': '9GWX3F4V+3M'}, 'reference': 'ChIJC0D0DQz-OEQR5iav36VWsZE', 'scope': 'GOOGLE', 'types': ['gas_station', 'point_of_interest', 'establishment'], 'vicinity': 'Островной г, Ostrovnoy'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 68.0578204, 'lng': 39.4928155}, 'viewport': {'northeast': {'lat': 68.0591220802915, 'lng': 39.4956069}, 'southwest': {'lat': 68.0564241197085, 'lng': 39.48444130000001}}}, 'icon': 'https://maps.gsta ...

# %%
hotel_df.to_csv("hotel_Output.csv")

hotel_df.head(1)

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
for index, row in 
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
