# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup as bs

# %%
url="https://www.wolterskluwercdi.com/drug-data/drug-interaction-allergy-screening/"

# %%
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
x=bs(response.text,'html.parser')
display(x)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="ie6 ie"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="ie7 ie"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="ie8 ie"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="ie9 ie"> <![endif]-->
# <!--[if (gt IEMobile 7)|!(IEMobile)|!(IE)]><!--><html lang="en" xmlns="http://www.w3.org/1999/xhtml"><!--<![endif]-->
# <head>
# <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
# <title>Drug Interaction &amp; Allergy Screening | Clinical Drug Information</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="www.pages05.net,checkout.netsuite.com,forms.netsuite.com,webstore.lexi.com,wolterskluwercdi.com,www.wolterskluwercdi.com" name="com.silverpop.brandeddomains">
# ...
