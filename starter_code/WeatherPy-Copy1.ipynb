# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

 #Output File (CSV)
df = pd.read_csv("../output_data/cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 584

# %% [markdown]
# ## Generate Cities List

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?"
units="imperial"
weather_key="d51879dc8581dbf6ee43ee85a3a06d04"
city="kansas city"
#building query
query_url= f"{base_url}appid={weather_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=d51879dc8581dbf6ee43ee85a3a06d04&units=imperial&q='

# %%
weather_json=requests.get(query_url+city)
weather_response=weather_json.json()
weather_response
# Out:
# {'coord': {'lon': -94.58, 'lat': 39.1},
#  'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'},
#   {'id': 200,
#    'main': 'Thunderstorm',
#    'description': 'thunderstorm with light rain',
#    'icon': '11d'}],
#  'base': 'stations',
#  'main': {'temp': 68.25,
#   'feels_like': 70.07,
#   'temp_min': 66.99,
#   'temp_max': 69.8,
#   'pressure': 1015,
#   'humidity': 88},
#  'visibility': 4828,
#  'wind': {'speed': 5.82, 'deg': 340},
#  'clouds': {'all': 90},
#  'dt': 1598708397,
#  'sys': {'type': 1,
#   'id': 4903,
#   'country': 'US',
#   'sunrise': 1598701500,
#   'sunset': 1598748816},
#  'timezone': -18000,
#  'id': 4393217,
#  'name': 'Kansas City',
#  'cod': 200}

# %%
final_url= f"{base_url}appid={weather_key}&units={units}&q="
final_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=d51879dc8581dbf6ee43ee85a3a06d04&units=imperial&q='

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather=[]
counter=0
#set_record = 1
for city in cities:
   
    print(f'the record {counter} of set 1 | {city}')
    weather_response = requests.get(final_url+'city')
    weather_json = weather_response.json()
    try:
        
        #print(json.dumps(weather_json))
        cityDict= {
        "city_name":weather_json["name"],
        "cloudiness" : weather_json["clouds"]["all"],
        "Country":weather_json["sys"]["country"],
        "Date":weather_json["dt"],
        "Humidity":weather_json["main"]["humidity"]
        Lat=weather_json["coord"]["lat"]
        Lng=weather_json["coord"]["lon"]
        Max_Temp=weather_json["main"]["temp_max"]
        Wind_Speed=weather_json["wind"]["speed"]}
#         print(Lat,Lng)
                
        city_weather.append({"City": city,
                   "Cloudiness": cloudiness,
                   "Country":Country,
                   "Date":Date,
                   "Humidity":Humidity,
                   "Lat":Lat,
                   "Lng":Lng,
                   "Max_Temp":Max_Temp,
                   "Wind_Speed":Wind_speed
        })
        counter+=1  
        print(counter,weather_json["name"],weather_json["id"])
        
    except:
        print("city not found")
        
        #pass
    
#print(city_weather)
# Out:
# the record 0 of set 1 | carnarvon
# city not found
# the record 0 of set 1 | bredasdorp
# city not found
# the record 0 of set 1 | padang
# city not found
# the record 0 of set 1 | bluff
# city not found
# the record 0 of set 1 | pevek
# city not found
# the record 0 of set 1 | wattegama
# city not found
# the record 0 of set 1 | bocas del toro
# city not found
# the record 0 of set 1 | vao
# city not found
# the record 0 of set 1 | yebaishou
# city not found
# the record 0 of set 1 | albany
# city not found
# the record 0 of set 1 | saldanha
# city not found
# the record 0 of set 1 | khatanga
# city not found
# the record 0 of set 1 | coquimbo
# city not found
# the record 0 of set 1 | rikitea
# city not found
# the record 0 of set 1 | kurmanayevka
# city not found
# the record 0 of set 1 | skalistyy
# city not found
# the record 0 of set 1 | ushuaia
# city not found
# the record 0 of set 1 | punta arenas
# city not found
# the record 0 of set 1 | comrie
# city not found
# the record 0 of set 1 | mar del plata
# city not found
# the record 0 of set 1 | grand river south east
# city not found
# the record 0 of set 1 | guerrero negro
# city not found
# the record 0 of set 1 | taolanaro
# city not found
# the record 0 of set 1 | ozgon
# city not found
# the record 0 of set 1 | busselton
# city not found
# the record 0 of set 1 | qasigiannguit
# city not found
# the record 0 of set 1 | geraldton
# city not found
# the record 0 of set 1 | hithadhoo
# city not found
# the record 0 of set 1 | hobart
# city not found
# the record 0 of set 1 | muli
# city not found
# the record 0 of set 1 | atuona
# city not found
# the record 0 of set 1 | arlit
# city not found
# the record 0 of set 1 | illoqqortoormiut
# city not found
# the record 0 of set 1 | roald
# city not found
# the record 0 of set 1 | sungaipenuh
# city not found
# the record 0 of set 1 | codrington
# city not found
# the record 0 of set 1 | phan rang
# city not found
# the record 0 of set 1 | zhenjiang
# city not found
# the record 0 of set 1 | batemans bay
# city not found
# the record 0 of set 1 | torbay
# city not found
# the record 0 of set 1 | santiago del estero
# city not found
# the record 0 of set 1 | hilo
# city not found
# the record 0 of set 1 | new norfolk
# city not found
# the record 0 of set 1 | hermanus
# city not found
# the record 0 of set 1 | mataura
# city not found
# the record 0 of set 1 | constitucion
# city not found
# the record 0 of set 1 | esperance
# city not found
# the record 0 of set 1 | yumen
# city not found
# the record 0 of set 1 | petropavlovsk-kamchatskiy
# city not found
# the record 0 of set 1 | honningsvag
# city not found
# the record 0 of set 1 | shu
# city not found
# the record 0 of set 1 | faanui
# city not found
# the record 0 of set 1 | sibolga
# city not found
# the record 0 of set 1 | agva
# city not found
# the record 0 of set 1 | korla
# city not found
# the record 0 of set 1 | hambantota
# city not found
# the record 0 of set 1 | alenquer
# city not found
# the record 0 of set 1 | jamestown
# city not found
# the record 0 of set 1 | letterkenny
# city not found
# the record 0 of set 1 | kinablangan
# city not found
# the record 0 of set 1 | luganville
# city not found
# the record 0 of set 1 | lebu
# city not found
# the record 0 of set 1 | east london
# city not found
# the record 0 of set 1 | matrei
# city not found
# the record 0 of set 1 | vaini
# city not found
# the record 0 of set 1 | kayes
# city not found
# the record 0 of set 1 | bandarbeyla
# city not found
# the record 0 of set 1 | koutiala
# city not found
# the record 0 of set 1 | georgetown
# city not found
# the record 0 of set 1 | bulawayo
# city not found
# the record 0 of set 1 | the valley
# city not found
# the record 0 of set 1 | norman wells
# city not found
# the record 0 of set 1 | sao jose da coroa grande
# city not found
# the record 0 of set 1 | monte alegre
# city not found
# the record 0 of set 1 | belushya guba
# city not found
# the record 0 of set 1 | belyy yar
# city not found
# the record 0 of set 1 | maceio
# city not found
# the record 0 of set 1 | emba
# city not found
# the record 0 of set 1 | ancud
# city not found
# the record 0 of set 1 | barentsburg
# city not found
# the record 0 of set 1 | broken hill
# city not found
# the record 0 of set 1 | port hardy
# city not found
# the record 0 of set 1 | port elizabeth
# city not found
# the record 0 of set 1 | tilichiki
# city not found
# the record 0 of set 1 | halifax
# city not found
# the record 0 of set 1 | vestmannaeyjar
# city not found
# the record 0 of set 1 | port alfred
# city not found
# the record 0 of set 1 | rawson
# city not found
# the record 0 of set 1 | palmas bellas
# city not found
# the record 0 of set 1 | casino
# city not found
# the record 0 of set 1 | dwarka
# city not found
# the record 0 of set 1 | yellowknife
# city not found
# the record 0 of set 1 | khor
# city not found
# the record 0 of set 1 | buraydah
# city not found
# the record 0 of set 1 | ahipara
# city not found
# the record 0 of set 1 | aykhal
# city not found
# the record 0 of set 1 | avarua
# city not found
# the record 0 of set 1 | tacoronte
# city not found
# the record 0 of set 1 | nanortalik
# city not found
# the record 0 of set 1 | diamantino
# city not found
# the record 0 of set 1 | ribeira grande
# city not found
# the record 0 of set 1 | butaritari
# city not found
# the record 0 of set 1 | port keats
# city not found
# the record 0 of set 1 | tiksi
# city not found
# the record 0 of set 1 | yaan
# city not found
# the record 0 of set 1 | lata
# city not found
# the record 0 of set 1 | pundaguitan
# city not found
# the record 0 of set 1 | tuktoyaktuk
# city not found
# the record 0 of set 1 | beringovskiy
# city not found
# the record 0 of set 1 | toamasina
# city not found
# the record 0 of set 1 | qaanaaq
# city not found
# the record 0 of set 1 | nizhneyansk
# city not found
# the record 0 of set 1 | goundam
# city not found
# the record 0 of set 1 | port blair
# city not found
# the record 0 of set 1 | thompson
# city not found
# the record 0 of set 1 | kloulklubed
# city not found
# the record 0 of set 1 | puerto ayora
# city not found
# the record 0 of set 1 | sao joao da barra
# city not found
# the record 0 of set 1 | bathsheba
# city not found
# the record 0 of set 1 | severo-kurilsk
# city not found
# the record 0 of set 1 | khalkhal
# city not found
# the record 0 of set 1 | mto wa mbu
# city not found
# the record 0 of set 1 | hasaki
# city not found
# the record 0 of set 1 | ilheus
# city not found
# the record 0 of set 1 | mandalgovi
# city not found
# the record 0 of set 1 | tura
# city not found
# the record 0 of set 1 | vila velha
# city not found
# the record 0 of set 1 | arraial do cabo
# city not found
# the record 0 of set 1 | amapa
# city not found
# the record 0 of set 1 | sarangani
# city not found
# the record 0 of set 1 | cockburn town
# city not found
# the record 0 of set 1 | wulanhaote
# city not found
# the record 0 of set 1 | putten
# city not found
# the record 0 of set 1 | namibe
# city not found
# the record 0 of set 1 | mogadishu
# city not found
# the record 0 of set 1 | otane
# city not found
# the record 0 of set 1 | pankovka
# city not found
# the record 0 of set 1 | northam
# city not found
# the record 0 of set 1 | amderma
# city not found
# the record 0 of set 1 | zabrze
# city not found
# the record 0 of set 1 | along
# city not found
# the record 0 of set 1 | solnechnyy
# city not found
# the record 0 of set 1 | cap-aux-meules
# city not found
# the record 0 of set 1 | ponta do sol
# city not found
# the record 0 of set 1 | ahar
# city not found
# the record 0 of set 1 | huangchuan
# city not found
# the record 0 of set 1 | chokurdakh
# city not found
# the record 0 of set 1 | povenets
# city not found
# the record 0 of set 1 | kapaa
# city not found
# the record 0 of set 1 | hirara
# city not found
# the record 0 of set 1 | kargopol
# city not found
# the record 0 of set 1 | margate
# city not found
# the record 0 of set 1 | mys shmidta
# city not found
# the record 0 of set 1 | dikson
# city not found
# the record 0 of set 1 | akcaabat
# city not found
# the record 0 of set 1 | cam ranh
# city not found
# the record 0 of set 1 | marawi
# city not found
# the record 0 of set 1 | naze
# city not found
# the record 0 of set 1 | wajid
# city not found
# the record 0 of set 1 | saint george
# city not found
# the record 0 of set 1 | sarkand
# city not found
# the record 0 of set 1 | belmonte
# city not found
# the record 0 of set 1 | alofi
# city not found
# the record 0 of set 1 | castro
# city not found
# the record 0 of set 1 | bengkulu
# city not found
# the record 0 of set 1 | dajal
# city not found
# the record 0 of set 1 | clyde river
# city not found
# the record 0 of set 1 | mount isa
# city not found
# the record 0 of set 1 | negombo
# city not found
# the record 0 of set 1 | broome
# city not found
# the record 0 of set 1 | cape town
# city not found
# the record 0 of set 1 | hami
# city not found
# the record 0 of set 1 | diveyevo
# city not found
# the record 0 of set 1 | takaungu
# city not found
# the record 0 of set 1 | tabou
# city not found
# the record 0 of set 1 | orlik
# city not found
# the record 0 of set 1 | tasiilaq
# city not found
# the record 0 of set 1 | saint-philippe
# city not found
# the record 0 of set 1 | upernavik
# city not found
# the record 0 of set 1 | pangnirtung
# city not found
# the record 0 of set 1 | takoradi
# city not found
# the record 0 of set 1 | barabai
# city not found
# the record 0 of set 1 | karoi
# city not found
# the record 0 of set 1 | cartagena
# city not found
# the record 0 of set 1 | cap malheureux
# city not found
# the record 0 of set 1 | fort nelson
# city not found
# the record 0 of set 1 | te anau
# city not found
# the record 0 of set 1 | san quintin
# city not found
# the record 0 of set 1 | monrovia
# city not found
# the record 0 of set 1 | attawapiskat
# city not found
# the record 0 of set 1 | hofn
# city not found
# the record 0 of set 1 | oranjemund
# city not found
# the record 0 of set 1 | villarrica
# city not found
# the record 0 of set 1 | saleaula
# city not found
# the record 0 of set 1 | nicoya
# city not found
# the record 0 of set 1 | kaitangata
# city not found
# the record 0 of set 1 | kahului
# city not found
# the record 0 of set 1 | eldikan
# city not found
# the record 0 of set 1 | gondanglegi
# city not found
# the record 0 of set 1 | narsaq
# city not found
# the record 0 of set 1 | yulara
# city not found
# the record 0 of set 1 | yarim
# city not found
# the record 0 of set 1 | vila do maio
# city not found
# the record 0 of set 1 | calamar
# city not found
# the record 0 of set 1 | kodiak
# city not found
# the record 0 of set 1 | kassala
# city not found
# the record 0 of set 1 | le vauclin
# city not found
# the record 0 of set 1 | smithers
# city not found
# the record 0 of set 1 | ngunguru
# city not found
# the record 0 of set 1 | sorland
# city not found
# the record 0 of set 1 | shirokiy
# city not found
# the record 0 of set 1 | saskylakh
# city not found
# the record 0 of set 1 | evanston
# city not found
# the record 0 of set 1 | husavik
# city not found
# the record 0 of set 1 | havelock
# city not found
# the record 0 of set 1 | puerto leguizamo
# city not found
# the record 0 of set 1 | etawah
# city not found
# the record 0 of set 1 | karratha
# city not found
# the record 0 of set 1 | burns lake
# city not found
# the record 0 of set 1 | ulagan
# city not found
# the record 0 of set 1 | muisne
# city not found
# the record 0 of set 1 | cidreira
# city not found
# the record 0 of set 1 | waingapu
# city not found
# the record 0 of set 1 | quatre cocos
# city not found
# the record 0 of set 1 | lakefield
# city not found
# the record 0 of set 1 | cabo san lucas
# city not found
# the record 0 of set 1 | magrath
# city not found
# the record 0 of set 1 | hoi an
# city not found
# the record 0 of set 1 | flin flon
# city not found
# the record 0 of set 1 | mahebourg
# city not found
# the record 0 of set 1 | bethel
# city not found
# the record 0 of set 1 | tindivanam
# city not found
# the record 0 of set 1 | severnoye
# city not found
# the record 0 of set 1 | gat
# city not found
# the record 0 of set 1 | burlington
# city not found
# the record 0 of set 1 | malwan
# city not found
# the record 0 of set 1 | kruisfontein
# city not found
# the record 0 of set 1 | nikolskoye
# city not found
# the record 0 of set 1 | grand gaube
# city not found
# the record 0 of set 1 | iberia
# city not found
# the record 0 of set 1 | zabaykalsk
# city not found
# the record 0 of set 1 | sembe
# city not found
# the record 0 of set 1 | slave lake
# city not found
# the record 0 of set 1 | tunduru
# city not found
# the record 0 of set 1 | basco
# city not found
# the record 0 of set 1 | jos
# city not found
# the record 0 of set 1 | tres arroyos
# city not found
# the record 0 of set 1 | taseyevo
# city not found
# the record 0 of set 1 | sobolevo
# city not found
# the record 0 of set 1 | tsiroanomandidy
# city not found
# the record 0 of set 1 | saint-ambroise
# city not found
# the record 0 of set 1 | kawhia
# city not found
# the record 0 of set 1 | chissamba
# city not found
# the record 0 of set 1 | altay
# city not found
# the record 0 of set 1 | jhinjhak
# city not found
# the record 0 of set 1 | barrow
# city not found
# the record 0 of set 1 | dhidhdhoo
# city not found
# the record 0 of set 1 | oyek
# city not found
# the record 0 of set 1 | sioux lookout
# city not found
# the record 0 of set 1 | loudi
# city not found
# the record 0 of set 1 | kultuk
# city not found
# the record 0 of set 1 | iskateley
# city not found
# the record 0 of set 1 | bilma
# city not found
# the record 0 of set 1 | brae
# city not found
# the record 0 of set 1 | lincoln
# city not found
# the record 0 of set 1 | longyearbyen
# city not found
# the record 0 of set 1 | monterey
# city not found
# the record 0 of set 1 | yambio
# city not found
# the record 0 of set 1 | vila franca do campo
# city not found
# the record 0 of set 1 | port hawkesbury
# city not found
# the record 0 of set 1 | hay river
# city not found
# the record 0 of set 1 | nyzy
# city not found
# the record 0 of set 1 | saint-augustin
# city not found
# the record 0 of set 1 | mitsamiouli
# city not found
# the record 0 of set 1 | chuy
# city not found
# the record 0 of set 1 | cabedelo
# city not found
# the record 0 of set 1 | owosso
# city not found
# the record 0 of set 1 | moron
# city not found
# the record 0 of set 1 | saurimo
# city not found
# the record 0 of set 1 | chalmette
# city not found
# the record 0 of set 1 | novyye burasy
# city not found
# the record 0 of set 1 | sines
# city not found
# the record 0 of set 1 | bonnyville
# city not found
# the record 0 of set 1 | samusu
# city not found
# the record 0 of set 1 | khandbari
# city not found
# the record 0 of set 1 | chagda
# city not found
# the record 0 of set 1 | asau
# city not found
# the record 0 of set 1 | zhangye
# city not found
# the record 0 of set 1 | shizunai
# city not found
# the record 0 of set 1 | fredericksburg
# city not found
# the record 0 of set 1 | neuquen
# city not found
# the record 0 of set 1 | launceston
# city not found
# the record 0 of set 1 | sinnamary
# city not found
# the record 0 of set 1 | bubaque
# city not found
# the record 0 of set 1 | nalbari
# city not found
# the record 0 of set 1 | djibo
# city not found
# the record 0 of set 1 | galle
# city not found
# the record 0 of set 1 | adrar
# city not found
# the record 0 of set 1 | mehamn
# city not found
# the record 0 of set 1 | gifhorn
# city not found
# the record 0 of set 1 | kavaratti
# city not found
# the record 0 of set 1 | pringsewu
# city not found
# the record 0 of set 1 | touros
# city not found
# the record 0 of set 1 | binga
# city not found
# the record 0 of set 1 | sao filipe
# city not found
# the record 0 of set 1 | kanniyakumari
# city not found
# the record 0 of set 1 | sabang
# city not found
# the record 0 of set 1 | daitari
# city not found
# the record 0 of set 1 | san joaquin
# city not found
# the record 0 of set 1 | nishihara
# city not found
# the record 0 of set 1 | hobyo
# city not found
# the record 0 of set 1 | karkaralinsk
# city not found
# the record 0 of set 1 | necochea
# city not found
# the record 0 of set 1 | hailun
# city not found
# the record 0 of set 1 | port-gentil
# city not found
# the record 0 of set 1 | salalah
# city not found
# the record 0 of set 1 | airai
# city not found
# the record 0 of set 1 | umzimvubu
# city not found
# the record 0 of set 1 | dongsheng
# city not found
# the record 0 of set 1 | yar-sale
# city not found
# the record 0 of set 1 | martapura
# city not found
# the record 0 of set 1 | goderich
# city not found
# the record 0 of set 1 | ilulissat
# city not found
# the record 0 of set 1 | acarau
# city not found
# the record 0 of set 1 | develi
# city not found
# the record 0 of set 1 | lahat
# city not found
# the record 0 of set 1 | barguzin
# city not found
# the record 0 of set 1 | bambous virieux
# city not found
# the record 0 of set 1 | mount gambier
# city not found
# the record 0 of set 1 | dehui
# city not found
# the record 0 of set 1 | fairbanks
# city not found
# the record 0 of set 1 | pacific grove
# city not found
# the record 0 of set 1 | sentyabrskiy
# city not found
# the record 0 of set 1 | makakilo city
# city not found
# the record 0 of set 1 | leningradskiy
# city not found
# the record 0 of set 1 | ixtapa
# city not found
# the record 0 of set 1 | mayumba
# city not found
# the record 0 of set 1 | roebourne
# city not found
# the record 0 of set 1 | sarahan
# city not found
# the record 0 of set 1 | rio gallegos
# city not found
# the record 0 of set 1 | pinega
# city not found
# the record 0 of set 1 | pisco
# city not found
# the record 0 of set 1 | carutapera
# city not found
# the record 0 of set 1 | maryville
# city not found
# the record 0 of set 1 | victoria
# city not found
# the record 0 of set 1 | rabo de peixe
# city not found
# the record 0 of set 1 | la ronge
# city not found
# the record 0 of set 1 | dawlatabad
# city not found
# the record 0 of set 1 | rorvik
# city not found
# the record 0 of set 1 | rincon
# city not found
# the record 0 of set 1 | hamilton
# city not found
# the record 0 of set 1 | mao
# city not found
# the record 0 of set 1 | new haven
# city not found
# the record 0 of set 1 | horki
# city not found
# the record 0 of set 1 | dutse
# city not found
# the record 0 of set 1 | tessalit
# city not found
# the record 0 of set 1 | poya
# city not found
# the record 0 of set 1 | marsa matruh
# city not found
# the record 0 of set 1 | nkhotakota
# city not found
# the record 0 of set 1 | verkhoyansk
# city not found
# the record 0 of set 1 | puqi
# city not found
# the record 0 of set 1 | provideniya
# city not found
# the record 0 of set 1 | college
# city not found
# the record 0 of set 1 | nijar
# city not found
# the record 0 of set 1 | banepa
# city not found
# the record 0 of set 1 | tumannyy
# city not found
# the record 0 of set 1 | lagoa
# city not found
# the record 0 of set 1 | puri
# city not found
# the record 0 of set 1 | tsihombe
# city not found
# the record 0 of set 1 | antofagasta
# city not found
# the record 0 of set 1 | yerbogachen
# city not found
# the record 0 of set 1 | nalut
# city not found
# the record 0 of set 1 | krasnoselkup
# city not found
# the record 0 of set 1 | puro
# city not found
# the record 0 of set 1 | santiago
# city not found
# the record 0 of set 1 | lompoc
# city not found
# the record 0 of set 1 | dolores hidalgo
# city not found
# the record 0 of set 1 | kalevala
# city not found
# the record 0 of set 1 | zehdenick
# city not found
# the record 0 of set 1 | nantucket
# city not found
# the record 0 of set 1 | kungurtug
# city not found
# the record 0 of set 1 | kirakira
# city not found
# the record 0 of set 1 | umm lajj
# city not found
# the record 0 of set 1 | bilibino
# city not found
# the record 0 of set 1 | kieta
# city not found
# the record 0 of set 1 | bonavista
# city not found
# the record 0 of set 1 | lasa
# city not found
# the record 0 of set 1 | grande prairie
# city not found
# the record 0 of set 1 | puerto escondido
# city not found
# the record 0 of set 1 | kabare
# city not found
# the record 0 of set 1 | naryan-mar
# city not found
# the record 0 of set 1 | bardiyah
# city not found
# the record 0 of set 1 | maine-soroa
# city not found
# the record 0 of set 1 | santa quiteria
# city not found
# the record 0 of set 1 | bo rai
# city not found
# the record 0 of set 1 | meyungs
# city not found
# the record 0 of set 1 | caravelas
# city not found
# the record 0 of set 1 | les cayes
# city not found
# the record 0 of set 1 | vaitupu
# city not found
# the record 0 of set 1 | jiangyou
# city not found
# the record 0 of set 1 | kapoeta
# city not found
# the record 0 of set 1 | aswan
# city not found
# the record 0 of set 1 | klaksvik
# city not found
# the record 0 of set 1 | labuhan
# city not found
# the record 0 of set 1 | bolungarvik
# city not found
# the record 0 of set 1 | kupang
# city not found
# the record 0 of set 1 | sorvag
# city not found
# the record 0 of set 1 | dingle
# city not found
# the record 0 of set 1 | lavrentiya
# city not found
# the record 0 of set 1 | urumqi
# city not found
# the record 0 of set 1 | banda aceh
# city not found
# the record 0 of set 1 | keetmanshoop
# city not found
# the record 0 of set 1 | isetskoye
# city not found
# the record 0 of set 1 | ouadda
# city not found
# the record 0 of set 1 | laguna
# city not found
# the record 0 of set 1 | ormara
# city not found
# the record 0 of set 1 | skibbereen
# city not found
# the record 0 of set 1 | alto araguaia
# city not found
# the record 0 of set 1 | alibag
# city not found
# the record 0 of set 1 | chara
# city not found
# the record 0 of set 1 | kiunga
# city not found
# the record 0 of set 1 | tromso
# city not found
# the record 0 of set 1 | turukhansk
# city not found
# the record 0 of set 1 | itaituba
# city not found
# the record 0 of set 1 | rocha
# city not found
# the record 0 of set 1 | kavieng
# city not found
# the record 0 of set 1 | hovd
# city not found
# the record 0 of set 1 | sikonge
# city not found
# the record 0 of set 1 | ruatoria
# city not found
# the record 0 of set 1 | pingliang
# city not found
# the record 0 of set 1 | gravelbourg
# city not found
# the record 0 of set 1 | vanimo
# city not found
# the record 0 of set 1 | pingzhuang
# city not found
# the record 0 of set 1 | ayagoz
# city not found
# the record 0 of set 1 | ghanzi
# city not found
# the record 0 of set 1 | itarema
# city not found
# the record 0 of set 1 | kalamakion
# city not found
# the record 0 of set 1 | timra
# city not found
# the record 0 of set 1 | araouane
# city not found
# the record 0 of set 1 | talnakh
# city not found
# the record 0 of set 1 | katsuura
# city not found
# the record 0 of set 1 | aquiraz
# city not found
# the record 0 of set 1 | shimanovsk
# city not found
# the record 0 of set 1 | diego de almagro
# city not found
# the record 0 of set 1 | jiuquan
# city not found
# the record 0 of set 1 | gornopravdinsk
# city not found
# the record 0 of set 1 | uray
# city not found
# the record 0 of set 1 | sao felix do xingu
# city not found
# the record 0 of set 1 | yeppoon
# city not found
# the record 0 of set 1 | inuvik
# city not found
# the record 0 of set 1 | palabuhanratu
# city not found
# the record 0 of set 1 | rio grande
# city not found
# the record 0 of set 1 | praya
# city not found
# the record 0 of set 1 | tarrafal
# city not found
# the record 0 of set 1 | ilo
# city not found
# the record 0 of set 1 | waterloo
# city not found
# the record 0 of set 1 | grindavik
# city not found
# the record 0 of set 1 | pinotepa nacional
# city not found
# the record 0 of set 1 | camargo
# city not found
# the record 0 of set 1 | biltine
# city not found
# the record 0 of set 1 | port lincoln
# city not found
# the record 0 of set 1 | burgersdorp
# city not found
# the record 0 of set 1 | boa vista
# city not found
# the record 0 of set 1 | port hedland
# city not found
# the record 0 of set 1 | buin
# city not found
# the record 0 of set 1 | novouzensk
# city not found
# the record 0 of set 1 | san jose de guanipa
# city not found
# the record 0 of set 1 | beryslav
# city not found
# the record 0 of set 1 | dunedin
# city not found
# the record 0 of set 1 | kamaishi
# city not found
# the record 0 of set 1 | edd
# city not found
# the record 0 of set 1 | fortuna
# city not found
# the record 0 of set 1 | cherskiy
# city not found
# the record 0 of set 1 | bolshaya murta
# city not found
# the record 0 of set 1 | heihe
# city not found
# the record 0 of set 1 | waipawa
# city not found
# the record 0 of set 1 | avera
# city not found
# the record 0 of set 1 | baruun-urt
# city not found
# the record 0 of set 1 | juan aldama
# city not found
# the record 0 of set 1 | sorong
# city not found
# the record 0 of set 1 | uvarovka
# city not found
# the record 0 of set 1 | beaupre
# city not found
# the record 0 of set 1 | tabulbah
# city not found
# the record 0 of set 1 | cazaje
# city not found
# the record 0 of set 1 | ola
# city not found
# the record 0 of set 1 | betare oya
# city not found
# the record 0 of set 1 | sola
# city not found
# the record 0 of set 1 | soyo
# city not found
# the record 0 of set 1 | bodden town
# city not found
# the record 0 of set 1 | huadian
# city not found
# the record 0 of set 1 | thunder bay
# city not found
# the record 0 of set 1 | half moon bay
# city not found
# the record 0 of set 1 | sarh
# city not found
# the record 0 of set 1 | aklavik
# city not found
# the record 0 of set 1 | ilesha
# city not found
# the record 0 of set 1 | sainte-suzanne
# city not found
# the record 0 of set 1 | yazykovo
# city not found
# the record 0 of set 1 | ardakan
# city not found
# the record 0 of set 1 | pemba
# city not found
# the record 0 of set 1 | port pirie
# city not found
# the record 0 of set 1 | mayo
# city not found
# the record 0 of set 1 | rumboci
# city not found
# the record 0 of set 1 | brewster
# city not found
# the record 0 of set 1 | tecpan
# city not found
# the record 0 of set 1 | pankrushikha
# city not found
# the record 0 of set 1 | miskindzha
# city not found
# the record 0 of set 1 | studena
# city not found
# the record 0 of set 1 | ponta delgada
# city not found
# the record 0 of set 1 | rania
# city not found
# the record 0 of set 1 | north branch
# city not found
# the record 0 of set 1 | komsomolskiy
# city not found
# the record 0 of set 1 | donskoye
# city not found
# the record 0 of set 1 | abiy adi
# city not found
# the record 0 of set 1 | richards bay
# city not found
# the record 0 of set 1 | gualeguay
# city not found
# the record 0 of set 1 | ushtobe
# city not found
# the record 0 of set 1 | kholmogory
# city not found
# the record 0 of set 1 | tual
# city not found
# the record 0 of set 1 | kutum
# city not found
# the record 0 of set 1 | eureka
# city not found
# the record 0 of set 1 | evensk
# city not found
# the record 0 of set 1 | saint anthony
# city not found
# the record 0 of set 1 | sijunjung
# city not found
# the record 0 of set 1 | arman
# city not found
# the record 0 of set 1 | jalu
# city not found
# the record 0 of set 1 | vagur
# city not found
# the record 0 of set 1 | luderitz
# city not found
# the record 0 of set 1 | havre-saint-pierre
# city not found
# the record 0 of set 1 | katsiveli
# city not found
# the record 0 of set 1 | hede
# city not found
# the record 0 of set 1 | brusque
# city not found
# the record 0 of set 1 | kinango
# city not found
# the record 0 of set 1 | portland
# city not found
# the record 0 of set 1 | panjab
# city not found
# the record 0 of set 1 | mackay
# city not found
# the record 0 of set 1 | faya
# city not found
# the record 0 of set 1 | yanchukan
# city not found
# the record 0 of set 1 | karpenision
# city not found
# the record 0 of set 1 | arnprior
# city not found
# the record 0 of set 1 | mamallapuram
# city not found
# the record 0 of set 1 | matay
# city not found
# the record 0 of set 1 | tieli
# city not found
# the record 0 of set 1 | hihifo
# city not found
# the record 0 of set 1 | lichinga
# city not found
# the record 0 of set 1 | hopewell
# city not found
# the record 0 of set 1 | usinsk
# city not found
# the record 0 of set 1 | kholodnyy
# city not found
# the record 0 of set 1 | marcona
# city not found
# the record 0 of set 1 | saryshagan
# city not found
# the record 0 of set 1 | nelson bay
# city not found
# the record 0 of set 1 | prince rupert
# city not found
# the record 0 of set 1 | san patricio
# city not found
# the record 0 of set 1 | palmer
# city not found
# the record 0 of set 1 | wagar
# city not found
# the record 0 of set 1 | belaya gora
# city not found
# the record 0 of set 1 | los llanos de aridane
# city not found
# the record 0 of set 1 | raudeberg
# city not found
# the record 0 of set 1 | kingaroy
# city not found
# the record 0 of set 1 | pangody
# city not found
# the record 0 of set 1 | tynda
# city not found
# the record 0 of set 1 | hargeysa
# city not found
# the record 0 of set 1 | camacha
# city not found
# the record 0 of set 1 | andenes
# city not found
# the record 0 of set 1 | dunda
# city not found
# the record 0 of set 1 | mpigi
# city not found
# the record 0 of set 1 | kommunar
# city not found
# the record 0 of set 1 | terra santa
# city not found
# the record 0 of set 1 | belsand
# city not found
# the record 0 of set 1 | shestakovo
# city not found
# the record 0 of set 1 | sol-iletsk
# city not found
# the record 0 of set 1 | sarishabari
# city not found
# the record 0 of set 1 | sonoita
# city not found
# the record 0 of set 1 | talcahuano
# city not found
# the record 0 of set 1 | calama
# city not found
# the record 0 of set 1 | damghan
# city not found
# the record 0 of set 1 | atar
# city not found
# the record 0 of set 1 | kapuskasing
# city not found
# the record 0 of set 1 | jinchang
# city not found
# the record 0 of set 1 | labuan
# city not found
# the record 0 of set 1 | shelburne
# city not found
# the record 0 of set 1 | severnyy
# city not found
# the record 0 of set 1 | azangaro
# city not found
# the record 0 of set 1 | sistranda
# city not found
# the record 0 of set 1 | sahuaripa
# city not found

# %%
print( city_weather)
# df1=pd.DataFrame(city_weather)
# df1.head(4)
# Out:
# []

# %%
#set up a list to hold temperatures 
temperatures =[]
for city in cities:
#     Build query URL and request your results in Celsius
    query_url = f"{url}appid={weather_key}&q={city}&units={units}"
    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    temperature = weather_json["main"]["temp"]
    temperatures.append(temperature)
print(temperatures)
#     print(f"The temperature in {city} is {temperatures}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-3c80756f6b70> in <module>
#       7     weather_response = requests.get(query_url)
#       8     weather_json = weather_response.json()
# ----> 9     temperature = weather_json["main"]["temp"]
#      10     temperatures.append(temperature)
#      11 print(temperatures)
#
# KeyError: 'main'

# %%
# url = "http://api.openweathermap.org/data/2.5/weather?q="
# city = "London"
# unit_format = "&units=imperial"
# key = '&appid=' + weather_key
# # Build query URL
# query_url = url + city + key +unit_format
# # query_url

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df=pd.DataFrame(city_weather)
city_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# city_df.to_csv("output_data/cities_1.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum1=city_df.loc[city_df["Humidity"]>100]
hum1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-45d0e6916898> in <module>
# ----> 1 hum1=city_df.loc[city_df["Humidity"]>100]
#       2 hum1
#
# NameError: name 'city_df' is not defined

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
